# %% [markdown]
# ## Final Grade Claim

# %% [markdown]
# ![Screenshot (269).png](data:image/png;base64,...)

# %% [markdown]
# ## Top 3 Evidences

# %% [markdown]
# Divide Pair Conquer 11:

# %% [markdown]
# https://colab.research.google.com/github/HannahParker/cse380-notebooks/blob/master/11_1_About_Paths_in_Word_Graphs.ipynb#scrollTo=JPLq4YOJoLab&line=6&uniqifier=1

# %% [markdown]
# Class Directed Learning 12:

# %% [markdown]
# https://colab.research.google.com/github/HannahParker/cse380-notebooks/blob/master/12_3_About_Deterministic_Finite_Automata.ipynb#scrollTo=w_wpJ81v_c8r&line=1&uniqifier=1

# %% [markdown]
# Ponder and Prove 10:

# %% [markdown]
# https://colab.research.google.com/github/HannahParker/cse380-notebooks/blob/master/10_2_Ponder_and_Prove_Spanning_Trees.ipynb#scrollTo=EdAFiPvgsCS1&line=1&uniqifier=1
